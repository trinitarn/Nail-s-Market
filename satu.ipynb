# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
cosmetic=pd.read_csv("ecomcosdat.csv")

# %%
cosmetic
# Out:
#                                             product_name   website country  \
# 0      Carlton London Incense Eau da parfum, Premium ...  Flipkart   India
# 1      CHARLENE SPRAY MIST PERFUME 30 - INTIMATE (PAC...  Flipkart   India
# 2      CHARLENE SPRAY MIST PERFUME 30 - INTIMATE (PAC...  Flipkart   India
# 3      DENVER Black Code Perfume - 60 | Eau de Parfum...  Flipkart   India
# 4      Denver Hamilton Perfume - 100 | Long Lasting P...  Flipkart   India
# ...                                                  ...       ...     ...
# 12610  Bright Future - Smoothing & Brightening Concea...   Sephora   India
# 12611  Bright Future - Smoothing & Brightening Concea...   Sephora   India
# 12612                     Starlaa Rosy Bronze Blush Mini   Sephora   India
# 12613      Terra Golden Brick Red Blush Travel Size Mini   Sephora   India
# 12614       Peachin' Golden Peach Blush Travel Size Mini   Sephora   India
#
# ...

# %%
product_names = ['Nail', 'Nails']

# Filter for products containing any of the keywords
nail_products = cosmetic[cosmetic['product_name'].str.contains('|'.join(product_names), case=False)]

# Print the filtered DataFrame
print(nail_products)
# Out:
#                                             product_name   website country  \
# 2660   Cosmetic Grade 12 Pk Glitter Powder Kit - A Be...    Amazon   India
# 3525   Red Ballons Eye Gitter, Eye Shadow Glitter Pow...    Amazon   India
# 4208   LA Splash Cosmetics Metallic Champagne Loose G...    Amazon   India
# 5897   Mamaearth 100% Pure Castor Oil, Cold Pressed, ...    Amazon   India
# 6177   Organic Castor Hair Oil from Soulflower |Hair ...    Amazon   India
# 8847   G4U All in One (11 in 1) Makeup Kit With 2 Nai...    Amazon   India
# 8848   G4U All in One (11 in 1) Makeup Kit With 2 Nai...    Amazon   India
# 8849   G4U All in One (11 in 1) Makeup Kit With 2 Nai...    Amazon   India
# 8850   G4U All in One (11 in 1) Makeup Kit With 2 Nai...    Amazon   India
# 8851   G4U All in One (11 in 1) Makeup Kit With 2 Nai...    Amazon   India
# 8852   G4U All in One (11 in 1) Makeup Kit With 2 Nai...    Amazon   India
# ...

# %%
nail_products.to_csv('nail_products.csv', index=False)

# %%
cosmetic.columns
# Out:
# Index(['product_name', 'website', 'country', 'category', 'subcategory',
#        'title-href', 'price', 'brand', 'ingredients', 'form', 'type', 'color',
#        'size', 'rating', 'noofratings'],
#       dtype='object')

# %%
df=pd.read_csv("nail_products.csv")
brand=df["brand"].value_counts()
plt.pie(brand, labels=brand.index, autopct="%1.1f%%")
plt.title("Nail Competitors")
plt.show()

# %%
df=pd.read_csv("nail_products.csv")
type=df.dtypes
print(type)
# Out:
# product_name     object
# website          object
# country          object
# category         object
# subcategory      object
# title-href       object
# price           float64
# brand            object
# ingredients      object
# form             object
# type             object
# color            object
# size             object
# rating          float64
# noofratings      object
# dtype: object

# %%
df=pd.read_csv("nail_products.csv")
price=df["price"].value_counts()

# %%
print(df.columns)
# Out:
# Index(['product_name', 'website', 'country', 'category', 'subcategory',
#        'title-href', 'price', 'brand', 'ingredients', 'form', 'type', 'color',
#        'size', 'rating', 'noofratings'],
#       dtype='object')

# %%
# Calculate price statistics
min_price = df["price"].min()
max_price = df["price"].max()
mean_price = df["price"].mean()
median_price = df["price"].median()
std_dev = df["price"].std()
iqr = df["price"].quantile(0.75) - df["price"].quantile(0.25)

# %%
# Print the results
print("Price Range for Nail Products:")
print("Minimum Price:", min_price)
print("Maximum Price:", max_price)
print("Mean Price:", mean_price)
print("Median Price:", median_price)
# Out:
# Price Range for Nail Products:
# Minimum Price: 449.0
# Maximum Price: 9599.0
# Mean Price: 1981.27
# Median Price: 1699.0

# %%
df = pd.read_csv("nail_products.csv")

# Filter for nail products with a price of 449.0
nail_product_449 = df[(df["price"] == 449.0)]

# Extract the product name
product_name = nail_product_449["product_name"].values

# Print the product name
if len(product_name) > 0:
    print("Product Name:", product_name[0])
else:
    print("No nail product found with a price of 449.0")
# Out:
# Product Name: Red Ballons Eye Gitter, Eye Shadow Glitter Powder And Nail Art Decoration Set of 25 with Two Eye Glue Eye Shadow Glitter Powder Set And Nail Art Decoration

# %%
df = pd.read_csv("nail_products.csv")

# Filter for nail products with a price of 9599.0
nail_product_9599 = df[(df["price"] == 9599.0)]

# Extract the product name
product_name = nail_product_9599["product_name"].values

# Print the product name
if len(product_name) > 0:
    print("Product Name:", product_name[0])
else:
    print("No nail product found with a price of 9599.0")
# Out:
# Product Name: Cosmetic Grade 12 Pk Glitter Powder Kit - A Beautiful Mix of Ultra Fine & Fine Glitter Powder Safe for Skin Great for Body Tattoos, Makeup, Face, Hair, Lips, Soap, Lotion, & Nail Art (10  Jars)

# %%
df = pd.read_csv("nail_products.csv")

# Filter for nail products with a price of 1699.0
nail_product_1699 = df[(df["price"] == 1699.0)]

# Extract the product name
product_name = nail_product_1699["product_name"].values

# Print the product name
if len(product_name) > 0:
    print("Product Name:", product_name[0])
else:
    print("No nail product found with a price of 1699.0")
# Out:
# Product Name: G4U All in One (11 in 1) Makeup Kit With 2 Nail Polishs,3 Lipsticks,Eyeshadow,Penliner,Kajal, Lipliner,Foundation,Pouch Women Gift Set Makeup Kit 18032021A26

# %%
### demographic (age, gender, spending, income)

# %%
df = pd.read_csv("income_spending.csv")
plt.scatter(df['Annual Income (k$)'], df['Spending Score (1-100)'])
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Correlation Between Annual Income and Spending Score')
plt.show()

# %%
## male (age - spending)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# !pip install scipy
import scipy
from scipy.stats import pearsonr
# Out:
# ...
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/44.8 MB 2.2 MB/s eta 0:00:20
#    - -------------------------------------- 1.3/44.8 MB 2.3 MB/s eta 0:00:19
#    - -------------------------------------- 1.3/44.8 MB 2.3 MB/s eta 0:00:19
#    - -------------------------------------- 1.6/44.8 MB 1.5 MB/s eta 0:00:29
#    - -------------------------------------- 1.8/44.8 MB 1.7 MB/s eta 0:00:26
#    - -------------------------------------- 2.1/44.8 MB 1.4 MB/s eta 0:00:30
#    -- ------------------------------------- 2.4/44.8 MB 1.4 MB/s eta 0:00:31
#    -- ------------------------------------- 2.4/44.8 MB 1.4 MB/s eta 0:00:31
#    -- ------------------------------------- 2.4/44.8 MB 1.4 MB/s eta 0:00:31
#    -- ------------------------------------- 2.6/44.8 MB 1.2 MB/s eta 0:00:37
# ...

# %%
df = pd.read_csv("income_spending.csv")

# Filter for male customers
male_data = df[df["Genre"] == "Male"]

# Calculate correlation coefficient
correlation_coef, _ = pearsonr(male_data['Age'], male_data['Spending Score (1-100)'])

# Print the correlation coefficient
print("Correlation coefficient:", correlation_coef)

# Create a scatter plot
plt.scatter(male_data['Age'], male_data['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.title('Correlation Between Age and Spending Score for Male Customers')
plt.show()
# Out:
# Correlation coefficient: -0.2796276462749313

# %%
df = pd.read_csv("income_spending.csv")

# Filter for female customers
female_data = df[df["Genre"] == "Female"]

# Calculate correlation coefficient
correlation_coef, _ = pearsonr(female_data['Age'], female_data['Spending Score (1-100)'])

# Print the correlation coefficient
print("Correlation coefficient:", correlation_coef)

# Create a scatter plot
plt.scatter(female_data['Age'], female_data['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.title('Correlation Between Age and Spending Score for Female Customers')
plt.show()
# Out:
# Correlation coefficient: -0.37543858377804745

# %%
import pandas as pd

# %%
## marketing strategies

# %%
df=pd.read_csv("cust_segment.csv")
type=df.dtypes
print(type)
# Out:
# id                        int64
# age                       int64
# gender                   object
# income                    int64
# spending_score            int64
# membership_years          int64
# purchase_frequency        int64
# preferred_category       object
# last_purchase_amount    float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
# !pip install scipy
import scipy
from scipy.stats import pearsonr

# %%
df = pd.read_csv("cust_segment.csv")

# Filter for male customers
clothing_data = df[df["preferred_category"] == "Clothing"]

# Calculate correlation coefficient
correlation_coef, _ = pearsonr(clothing_data['purchase_frequency'], clothing_data['membership_years'])

# Print the correlation coefficient
print("Correlation coefficient:", correlation_coef)

# Create a scatter plot
plt.scatter(clothing_data['membership_years'], clothing_data['purchase_frequency'])
plt.ylabel('purchase_frequency')
plt.title('Correlation Between Membership Year and Purchase Frequency')
plt.show()
# Out:
# Correlation coefficient: 0.060487747054317434

# %%
import pandas as pd

# Assuming your data is in a CSV file named "campaign_data.csv"
data = pd.read_csv("Social_Media_Advertising.csv")

# Group the data by campaign goal and channel, then calculate the mean conversion rate
grouped_data = data.groupby(["Campaign_Goal", "Channel_Used"])["Conversion_Rate"].mean().reset_index()

# Find the best channel for each campaign goal
best_channels = grouped_data.groupby("Campaign_Goal").apply(lambda x: x.nlargest(1, "Conversion_Rate")).reset_index(drop=True)

# Print the results
print(best_channels)
# Out:
#       Campaign_Goal Channel_Used  Conversion_Rate
# 0   Brand Awareness    Pinterest         0.080310
# 1    Increase Sales      Twitter         0.080348
# 2  Market Expansion      Twitter         0.080704
# 3    Product Launch      Twitter         0.080481
# C:\Users\nitar\AppData\Local\Temp\ipykernel_11536\1750995161.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_channels = grouped_data.groupby("Campaign_Goal").apply(lambda x: x.nlargest(1, "Conversion_Rate")).reset_index(drop=True)

# %%
data = pd.read_csv("shopbehav.csv")
data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("shopbehav.csv")

# Filter for accessories
accessories = data[data["Category"] == "Accessories"].groupby("Season")

plt.bar(accessories['Season'], accessories['Purchase Amount (USD)'])  # Replace with accessories['Purchase Amount (USD)'] if you want individual values
plt.xlabel('Season')
plt.ylabel('Purchase Amount (USD)')
plt.title('Total Purchase Amount of Accessories Products')
plt.show()

# %%
print(total_purchase_amount)
# Out:
# 74200
